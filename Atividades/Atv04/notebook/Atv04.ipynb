// %% [markdown]
// # Exercício 01
// <p style="text-align:justify;">
// Crie um programa que armazene um vetor com as notas de dez alunos, calcule e imprima a média dessas notas e depois informe a quantidade de notas acima e abaixo da média calculada.
// </p>

// %%
import java.util.Random;

// public class Notas {
    // public static void main(String[] args) {
        float notas[] = new float[10], soma = 0;
        int ba = 0, ci = 0;
       
        Random random = new Random();
        for (int i = 0; i < 10; i++) {
            notas[i] = random.nextFloat()*101;
            soma += notas[i];
        }
        System.out.println("Media das notas:" + soma / 10);
        for (int i = 0; i < 10; i++) {
            System.out.println(notas[i]);
            if (notas[i] < soma / 10) {
                ba++;
            } else {
                ci++;
            }
        }
        System.out.println("Quantidade acima da media:" + ci + " Quantidade abaixo da media:" + ba);
        
    // }
// }
// Out:
// Media das notas:69.35646
// 73.07479
// 84.89478
// 0.8974418
// 75.44751
// 88.39899
// 84.21104
// 96.22651
// 80.01395
// 65.20132
// 45.198288
// Quantidade acima da media:7 Quantidade abaixo da media:3
// null

// %% [markdown]
// # Exercício 02
// <p style="text-align:justify;">
// Construa uma classe em Java que seja capaz de efetuar a leitura de uma matriz de valores reais de tamanho 3 x 3, calculando seu determinante.
// </p>

// %%
import java.util.Random;

// public class Determinante {
    // public static void main(String[] args) {
        float mat[][] = new float[3][3];
        float diagPrin1, diagPrin2, diagPrin3, diagSec1, diagSec2, diagSec3;
        float det = 0;
        
        Random random = new Random();
        for (int i = 0; i < 3; i++) {
            for (int j = 0; j < 3; j++) {
                mat[i][j] = random.nextFloat()*101;
            }
        }
        for (int i = 0; i < 3; i++) {
            for (int j = 0; j < 3; j++) {
                if (j % 3 == 0) {
                    System.out.println();
                } else {
                    System.out.print("\t");
                }
                System.out.print(mat[i][j]);

            }
        }

        diagPrin1 = mat[0][0] * mat[1][1] * mat[2][2];
        diagPrin2 = mat[0][1] * mat[1][2] * mat[2][0];
        diagPrin3 = mat[0][2] * mat[1][0] * mat[2][1];

        diagSec1 = mat[2][0] * mat[1][1] * mat[0][2];
        diagSec2 = mat[2][1] * mat[1][2] * mat[0][0];
        diagSec3 = mat[2][2] * mat[1][0] * mat[0][1];

        det = (diagPrin1 + diagPrin2 + diagPrin3) - (diagSec1 + diagSec2 + diagSec3);
        System.out.println();
        System.out.println("Determinante:" + det);
        

    // }
// }
// Out:
// 8.313313	45.619267	78.10685
// 37.97093	64.59048	96.46086
// 39.713703	99.39155	30.718998
// Determinante:152759.78
// null

// %% [markdown]
// # Exercício 03
// <p style="text-align:justify;">
// Faça uma classe contendo dois arrays do tipo inteiro, um chamado par e outro chamado ímpar. Cada array deve conter 10 elementos. A seguir, faça um laço de repetição com 10 iterações e que contenha internamente a geração randômica de números entre 1 e 20. Se o valor gerado for par, armazene no array chamado par, caso contrário, no array chamado impar. Ao final, apresente o conteúdo de cada um dos arrays.
// </p>

// %%
import java.util.Random;

// public class ParImpar {
    // public static void main(String[] args) {
        int par[] = new int[10], impar[] = new int[10];
        int x;
        Random random = new Random();
        for (int i = 0; i < 10; i++) {
            x = random.nextInt(21);
            if (x % 2 == 0) {
                par[i] = x;
            } else {
                impar[i] = x;
            }

        }
        System.out.println("Par");
        for (int i = 0; i < 10; i++) {
            if (par[i] != 0) {
                System.out.println(par[i]);
            }
        }
        System.out.println("Impar");
        for (int i = 0; i < 10; i++) {
            if (impar[i] != 0) {
                System.out.println(impar[i]);
            }
        }

    // }
// }
// Out:
// Par
// 14
// 8
// 12
// 12
// 12
// Impar
// 11
// 7
// 11
// 7
// null

// %% [markdown]
// # Exercício 04
// <p style="text-align:justify;">
// Usando um array unidimensional de 10 elementos do tipo String, faça uma classe que simule a ocupação de um estacionamento de veículos. Considere que a posição do array corresponde ao número da vaga e para cada vaga é armazenada a placa do veículo que está estacionado. Sua classe deve conter um laço de repetição simulando um menu que controle a entrada e a saída dos veículos com as opções: 1-Entrada, 2-Saída e 3-Listar situação atual e 4-Encerrar o programa. Se o usuário escolher 1, solicite o número da vaga e a placa do veículo; se escolher 2, solicite o número da vaga que será liberada e armazene o valor branco na posição correspondente ao array; se escolher 3, liste a situação atual apresentando em tela todos os elementos do array; quando for 4, encerre o laço e o programa.
// </p>

// %%
import java.util.*;

// public class Estacionamento {
    // public static void main(String[] args) {
        Scanner scanner = new Scanner(System.in);
        String[] vagas = new String[10];
        String placa;
        int numeroVaga;
        int opcao;
        do {
            System.out.println("Menu:");
            System.out.println("1 - Entrada");
            System.out.println("2 - Saída");
            System.out.println("3 - Listar situação atual");
            System.out.println("4 - Encerrar o programa");
            System.out.print("Escolha uma opção: ");
            opcao = scanner.nextInt();

            switch (opcao) {
                case 1:
                    System.out.print("Digite o número da vaga (0 a 9): ");
                    numeroVaga = scanner.nextInt();
                    System.out.print("Digite a placa do veículo: ");
                    placa = scanner.next();
                    vagas[numeroVaga] = placa;
                    break;
                case 2:
                    System.out.print("Digite o número da vaga (0 a 9): ");
                    numeroVaga = scanner.nextInt();
                    vagas[numeroVaga] = null;
                    break;
                case 3:
                    System.out.println("Situação atual do estacionamento:");
                    for (int i = 0; i < vagas.length; i++) {
                        placa = (vagas[i] != null) ? vagas[i] : "Vaga livre";
                        System.out.println("Vaga " + i + ": " + placa);
                    }
                    break;
                case 4:
                    System.out.println("Encerrando o programa...");
                    break;
            }
        } while (opcao != 4);
        scanner.close();
    // }
// }
// Out:
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Digite o número da vaga (0 a 9):
//  0
// Digite a placa do veículo:
//  nabc123
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// Vaga 0: nabc123
// Vaga 1: Vaga livre
// Vaga 2: Vaga livre
// Vaga 3: Vaga livre
// Vaga 4: Vaga livre
// Vaga 5: Vaga livre
// Vaga 6: Vaga livre
// Vaga 7: Vaga livre
// Vaga 8: Vaga livre
// Vaga 9: Vaga livre
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  2
// Digite o número da vaga (0 a 9):
//  0
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// Vaga 0: Vaga livre
// Vaga 1: Vaga livre
// Vaga 2: Vaga livre
// Vaga 3: Vaga livre
// Vaga 4: Vaga livre
// Vaga 5: Vaga livre
// Vaga 6: Vaga livre
// Vaga 7: Vaga livre
// Vaga 8: Vaga livre
// Vaga 9: Vaga livre
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  4
// Encerrando o programa...
// null

// %% [markdown]
// # Exercício 05
// <p style="text-align:justify;">
// Uma imagem é formada por pixels. Considere uma imagem com dimensão de 40 x 40 e faça uma classe que contenha um array bidimensional com essas dimensões. A seguir, para cada posição
// desse array bidimensional armazene um valor aleatório entre 0 e 255 (esses valores correspondem às tonalidades aplicadas sobre a imagem). Apresente em tela os 1600 valores gerados.
// </p>

// %%
import java.util.Random;

// public class Imagem{
    // public static void main(String[] args) {
        int[][] pixels = new int[40][40];
        Random random = new Random();
        for (int i = 0; i < pixels.length; i++) {
            for (int j = 0; j < pixels[i].length; j++) {
                pixels[i][j] = random.nextInt(256); // Gera um número aleatório entre 0 e 255
            }
        }
        System.out.println("Valores dos pixels da imagem:");
